# %%
from sbsim.smart_control.utils.config_generator import (
    generate_and_save_dataset,
    generate_config,
    visualize_config,
    BUILDING_SHAPES,
    CLIMATES,
)
from sbsim.smart_control.utils.scenario_generator import list_weather_presets

print("Available shapes:", BUILDING_SHAPES)
print("Available weather presets:", list_weather_presets())
# Out:
# Available shapes: ['rectangle', 'trapezoid', 'h_shape', 't_shape', 'pentagon', 'oval', 'u_shape', 'parallelogram', 'semicircle', 'triangle', 'composite']
# Available weather presets: ['temperate', 'tropical', 'hot_summer', 'cold_winter', 'mild_winter', 'mild_summer']

# %%
# Generate a building config - weather is handled separately via presets
# Each param can be:
# - single value: width=500
# - tuple range: width=(300, 600) -> random int in range
# - list of choices: building_shape=["rectangle", "h_shape"] -> picks one

config = generate_config(
    name="my_custom_env",
    seed=125347,
    building_shape=BUILDING_SHAPES,  # all shapes
    width=(400, 700),
    height=(300, 500),
    num_floors=(1, 4),
    min_room_size=(30, 60),
    shape_ratio=(0.2, 0.45),         # for H/T/U shapes
    composite_coverage=(0.4, 0.95),  # for composite shape
    num_ahus=(2, 6),
    occupants_per_zone=(1, 2),
)
print(config)
visualize_config(config)

# %%
# Interactive building generator - view one at a time, save or skip
import yaml
import os
from IPython.display import clear_output

BUILDING_SHAPES = [
    "composite"
]

saved_configs = []
seed_counter = 50

def generate_and_preview():
    global seed_counter
    seed_counter += 1
    
    config = generate_config(
        name=f"building_{seed_counter:04d}",
        seed=seed_counter,
        building_shape=BUILDING_SHAPES,
        width=(400, 700),
        height=(300, 500),
        num_floors=(1, 4),
        min_room_size=(30, 60),
        shape_ratio=(0.2, 0.45),
        composite_coverage=(0.4, 0.95),
        num_ahus=(2, 6),
        occupants_per_zone=(1, 2),
    )
    
    print(f"\n{'='*50}")
    print(f"Building: {config['name']}")
    print(f"Shape: {config['floor_plan']['building_shape']}")
    print(f"Size: {config['floor_plan']['width']}x{config['floor_plan']['height']}")
    print(f"Floors: {config['floor_plan']['num_floors']}, AHUs: {config['ahu']['num_ahus']}")
    print(f"{'='*50}\n")
    
    visualize_config(config)
    return config

def save_config(config, output_dir="buildings"):
    os.makedirs(output_dir, exist_ok=True)
    path = os.path.join(output_dir, f"{config['name']}.yaml")
    with open(path, "w") as f:
        yaml.dump(config, f, default_flow_style=False, sort_keys=False)
    saved_configs.append(path)
    print(f"Saved to {path}")

while True:
    clear_output(wait=True)
    print(f"[{len(saved_configs)} buildings saved so far]")
    config = generate_and_preview()
    
    choice = input("(s)ave / (n)ext / (q)uit: ").strip().lower()
    if choice == 's':
        save_config(config)
    elif choice == 'q':
        break

clear_output(wait=True)
print(f"Done! Saved {len(saved_configs)} buildings:")
for p in saved_configs:
    print(f"  {p}")
# Out:
# [8 buildings saved so far]
#
# ==================================================
# Building: building_0072
# Shape: composite
# Size: 495x388
# Floors: 3, AHUs: 6
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 52
#      50 clear_output(wait=True)
#      51 print(f"[{len(saved_configs)} buildings saved so far]")
# ---> 52 config = generate_and_preview()
#      54 choice = input("(s)ave / (n)ext / (q)uit: ").strip().lower()
#      55 if choice == 's':
#
# Cell In[4], line 38, in generate_and_preview()
#      35 print(f"Floors: {config['floor_plan']['num_floors']}, AHUs: {config['ahu']['num_ahus']}")
#      36 print(f"{'='*50}\n")
# ---> 38 visualize_config(config)
#      39 return config
#
# File ~/kaggle/smart_buildings_sim_generator/sbsim/smart_control/utils/config_generator.py:308, in visualize_config(config)
#     305 config_with_output = config.copy()
#     306 config_with_output['output_base_dir'] = temp_dir
# --> 308 result = generate_scenario_from_dict(config_with_output)
#     310 print(f"Generated {result['num_rooms']} rooms with {result['num_ahus']} AHUs")
#     311 print(f"Shape: {config['floor_plan']['building_shape']}")
#
# File ~/kaggle/smart_buildings_sim_generator/sbsim/smart_control/utils/scenario_generator.py:883, in generate_scenario_from_dict(config_dict)
#     880     temp_path = f.name
#     882 try:
# --> 883     result = generate_scenario(temp_path)
#     884 finally:
#     885     os.unlink(temp_path)
#
# File ~/kaggle/smart_buildings_sim_generator/sbsim/smart_control/utils/scenario_generator.py:726, in generate_scenario(config_path)
#     724 floor_plan_path = os.path.join(output_dir, "floor_plan.npy")
#     725 zone_map_path = os.path.join(output_dir, "zone_map.npy")
# --> 726 generator.save_for_simulator(floor_plan_path, zone_map_path)
#     728 # Get room count and assign to AHUs
#     729 num_rooms = generator.get_num_rooms()
#
# File ~/kaggle/smart_buildings_sim_generator/smart_buildings/smart_control/utils/floor_generator.py:724, in MultiFloorPlan.save_for_simulator(self, floor_plan_path, zone_map_path, padding)
#     721     base = floor_plan_path.replace('.npy', '')
#     722     zone_map_path = f"{base}_zones.npy"
# --> 724 np.save(floor_plan_path, self.export_for_simulator(padding=padding))
#     725 np.save(zone_map_path, self.export_zone_map(padding=padding))
#     726 return floor_plan_path, zone_map_path
#
# File ~/kaggle/smart_buildings_sim_generator/smart_buildings/smart_control/utils/floor_generator.py:689, in MultiFloorPlan.export_for_simulator(self, padding)
#     687 result = []
#     688 for i, floor in enumerate(self.floors):
# --> 689     result.append(floor.export_for_simulator(padding=padding))
#     690     if i < self.num_floors - 1:
#     691         result.append(separator)
#
# File ~/kaggle/smart_buildings_sim_generator/smart_buildings/smart_control/utils/floor_generator.py:485, in BSPFloorPlan.export_for_simulator(self, padding)
#     482             sim_grid[py, px] = 1
#     483         else:
#     484             # Interior space (floor and doors)
# --> 485             sim_grid[py, px] = 0
#     487 return sim_grid
#
# KeyboardInterrupt:
